# %% [markdown]
# # Automatyzacja pracy z danymi przestrzennymi w Pythonie i GeoPandas
#
# ![baner_2024.png](data:image/png;base64,...)

# %% [markdown]
# ## Meta
#
#
# - **Prowadzący**: Szymon Moliński (Digitree SA)
# - **Data**: 2024-06-26
# - **Miejsce**: Poznań

# %% [markdown]
# ## Program warsztatów
#
# 1. Praca w środowisku Google Colab i przygotowanie danych, wprowadzenie do `pandas` (notatnik `qgis_geopandas_workshops_1.ipynb`).
# 2. Podstawowe operacje - Geometria, `GeoSeries` i `GeoDataFrame` (notatnik `qgis_geopandas_workshops_2.ipynb`).
# 3. Funkcje pakietu `GeoPandas` (notatnik `qgis_geopandas_workshops_3.ipynb`).
# 4. Operacje przestrzenne (notatnik `qgis_geopandas_workshops_4.ipynb`).
# 5. Wstęp do uczenia maszynowego z GeoPandas (*feature engineering*) (notatnik `qgis_geopandas_workshops_5.ipynb`).
# 6. (Opcjonalnie) Geostatystyka z GeoPandas (katalog `6-optional` w repozytorium).
#
# REPOZYTORIUM: https://github.com/SimonMolinsky/iii-spotkanie-uzytkownikow-qgis
