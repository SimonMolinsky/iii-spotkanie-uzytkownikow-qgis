# %% [markdown]
# # Get more from Crime Rate data and other socio-economic indicators with Pyinterpolate
#
# ---
#
# ## URL:
#
# - [Article](https://ml-gis-service.com/index.php/2022/12/09/get-more-from-crime-rate-data-and-other-socio-economic-indicators-with-pyinterpolate/)
#
# ---
#
# ## Part 2: Explore and transform crime rate counts
#
#
# ### Block 1 - imports

# %%
import geopandas as gpd
import pyinterpolate as ptp

import matplotlib.pyplot as plt

# %% [markdown]
# ### Block 2 - read and analyze crime rates data

# %%
gdf = gpd.read_file('data/crime_rates_2019.shp')

# %%
# Take a look into a few random records

gdf.sample(5)
# Out:
#      Code                  Name   All  Criminal  Financial  SecurityAl  \
# 361  2464  Powiat m.Cz?stochowa  5539      3942       1052         407
# 80   2205       Powiat kartuski  1967      1403        291         216
# 82   3212       Powiat pyrzycki   730       529         49         102
# 216  1437     Powiat ?uromi?ski   465       241        144          72
# 213  1819    Powiat strzy?owski   483       282         73         117
#
#      SecurityRo  HealthAndL  Materials  Population  \
# 361         371         172       2468      220433
# 80          200          42       1081      139397
# 82           94          23        183       39336
# 216          72          11        205       38515
# 213         110          21        189       61386
#
#                                               geometry
# 361  POLYGON ((505296.358 318642.254, 505290.298 31...
# 80   POLYGON ((458746.153 730314.933, 458643.785 73...
# 82   POLYGON ((224017.437 605917.646, 226605.816 60...
# 216  POLYGON ((569022.384 550969.532, 569013.431 55...
# 213  POLYGON ((682500.738 227526.884, 682501.467 22...

# %%
# Core statistics

gdf.describe()
# Out:
#                 All      Criminal    Financial   SecurityAl   SecurityRo  \
# count    380.000000    380.000000   380.000000   380.000000   380.000000
# mean    2096.202632   1334.692105   493.071053   204.797368   187.542105
# std     3490.528307   2591.969861   867.368381   173.651483   153.895609
# min      293.000000    152.000000    26.000000    44.000000    38.000000
# 25%      898.250000    523.500000   123.000000   122.000000   113.000000
# 50%     1301.000000    795.500000   238.500000   173.000000   158.000000
# 75%     2034.250000   1236.000000   487.750000   238.750000   217.750000
# max    50387.000000  37413.000000  9776.000000  2413.000000  2118.000000
#
#        HealthAndL     Materials    Population
# count  380.000000    380.000000  3.800000e+02
# mean    43.634211    994.844737  1.010068e+05
# std     54.182438   2164.824078  1.198884e+05
# min      1.000000     87.000000  1.991400e+04
# 25%     20.750000    310.500000  5.497975e+04
# 50%     30.000000    495.500000  7.600700e+04
# 75%     47.250000    922.000000  1.114018e+05
# max    526.000000  32906.000000  1.790658e+06

# %%
# CRS

gdf.crs
# Out:
# <Derived Projected CRS: PROJCS["ETRF2000-PL / CS92",GEOGCS["ETRS89",DATUM[ ...>
# Name: ETRF2000-PL / CS92
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Transverse Mercator
# Datum: European Terrestrial Reference System 1989
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %% [markdown]
# ### Block 3 - histogram of raw counts

# %%
plt.figure(figsize=(12, 6))
gdf['All'].hist(grid=False, bins=20)
plt.title('Crime counts per county')
plt.show()

# %% [markdown]
# ### Block 4 - map of raw counts

# %%
gdf.plot(figsize=(10, 10), column='All', cmap='coolwarm', legend=True)
plt.title('Crimes (count) per county in Poland 2019')
plt.show()

# %% [markdown]
# ### Block 5 - transform counts to rates and show histogram

# %%
gdf['Crime Rate'] = (gdf['All'] / gdf['Population']) * 100000

plt.figure(figsize=(12, 6))
gdf['Crime Rate'].hist(grid=False, bins=20)
plt.title('Histogram of crime rates per 100 000 inhabitants in Polish counties')
plt.show()

# %% [markdown]
# ### Block 6 - map of crime rates

# %%
gdf.plot(figsize=(10, 10), column='Crime Rate', cmap='coolwarm', legend=True)
plt.title('Crime rates per county in Poland 2019 per 100k inhabitants')
plt.show()

# %% [markdown]
# ### Block 7 - save rates to file

# %%
df = gdf[['Crime Rate', 'Population', 'geometry', 'Code']]
df.columns = ['CrimeRate', 'Pop', 'geometry', 'Code']
df.to_file('data/crimerates.shp')

# %% [markdown]
# ---
